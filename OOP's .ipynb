# %% [markdown]
# Theory Questions

# %% [markdown]
# 1.  What is Object-Oriented Programming (OOP)?
#
# -> Object oriented programming is a programming paradigm that uses the concept of class and object.  It allows developers to structure programs using real-world entities, promoting modularity, reusability, and scalability.
#
# Key Concepts of OOP are:
# 1. Encapsulation
# 2. Abstraction
# 3. Inheritance
# 4. Polymorphism
# 5. Class
# 6. Object

# %% [markdown]
# 2. What is a class in OOP?
#
# -> Class are blueprint/template for creating an object. It defines attributes (variables) and methods (functions) that defines nature/ behaviour of the object.
#
# -> Name of class should always start with a capital letter.
#
# -> Key Points About Classes:
#
#   a) A class acts as a template, and objects are created based on this template.
#
#   b) It helps in organizing code efficiently by grouping related data and behavior.
#
#   c)A class does not occupy memory until an object is created from it.

# %%
#example of Q2

class Car:
  def accelerate(self):   #Function/menthod of class
    print("Car is accelerating")

a = Car()
a.accelerate()
# Out:
# Car is accelerating

# %% [markdown]
# 3. What is an object in OOP?
#
# -> Object is an instance of class. It represents real world entity that has attributes (data) and behaviors (methods).
#
# -> Key Points About Objects:
#
#    a) Objects are created based on a class (blueprint).
#
#    b) Each object has its own unique data (state) but shares the structure and behavior defined by the class.
#
#    c) Objects enable modularity and code reusability in programming.

# %%
#Q3 Example

class Car:
    def __init__(self, brand, model, year):
        self.brand = brand  # Attribute
        self.model = model  # Attribute
        self.year = year    # Attribute

    def display_info(self):  # Method
        return f"{self.year} {self.brand} {self.model}"

# Creating objects (instances of the Car class)
car1 = Car("Toyota", "Corolla", 2022)
car2 = Car("Honda", "Civic", 2023)

# Accessing object attributes and methods
print(car1.display_info())  # Output: 2022 Toyota Corolla
print(car2.display_info())  # Output: 2023 Honda Civic
# Out:
# 2022 Toyota Corolla
# 2023 Honda Civic

# %% [markdown]
# 4. What is the difference between abstraction and encapsulation?
#
# -> Abstraction means hides implementation details and shows only essential features whereas encapsulation hides data by restricting direct access and controlling modifications.
#
# -> Abstraction focuses on what an object does, not how it does it whereas encapsulation protects data and ensures controlled access through methods.

# %% [markdown]
# 5. What are dunder methods in Python?
#
# -> Dunder methods (short for "double underscore methods") are special built-in methods in Python that have double underscores (__) before and after their names, like __init__, __str__, and __add__. These methods are also called magic methods because they enable operator overloading, object representation, and customization of built-in behaviors.

# %% [markdown]
# 6. Explain the concept of inheritance in OOP?
#
# -> Inheritance is an Object-Oriented Programming (OOP) concept that allows a child class (subclass) to inherit attributes and methods from a parent class (superclass). It promotes code reusability, hierarchical relationships, and modularity.

# %% [markdown]
# 7. What is polymorphism in OOP?
#
# -> Polymorphism is an Object-Oriented Programming (OOP) principle that allows objects of different classes to be treated as objects of a common superclass. It enables the same method or function to have different behaviors based on the object calling it.

# %% [markdown]
# 8.  How is encapsulation achieved in Python?
#
# -> Encapsulation is one of the fundamental principles of Object-Oriented Programming (OOP) that restricts direct access to an object's data and allows modifications only through defined methods. It helps in data hiding, security, and better code organization.
#
# -> How Encapsulation is Achieved in Python?
#
#    Python achieves encapsulation using:
#
#    - Public Members (var) - Accessible anywhere.
#    - Protected Members (_var) - Should not be accessed directly, but can be used within subclasses.
#    - Private Members (__var) - Cannot be accessed directly outside the class (name-mangling applied).

# %% [markdown]
# 9. What is a constructor in Python?
#
# -> A constructor is a special method in Python that is automatically called when an object of a class is created. It is used to initialize the object's attributes. In Python, the constructor is defined using the __init__ method.

# %% [markdown]
# 10. What are class and static methods in Python?
#
# -> Class Method (@classmethod)
#    - Works on the class level, not instance level.
#    - Takes cls as the first parameter, which represents the class itself.
#    - Can modify class variables and apply changes to all instances.
#    - Defined using the @classmethod decorator.
#
# -> Static Method (@staticmethod)
#    - Does not take self or cls as parameters.
#    - Acts like a normal function inside a class but is logically related to the class.
#    - Cannot modify class or instance attributes.
#    - Defined using the @staticmethod decorator.

# %% [markdown]
# 11. What is method overloading in Python?
#
# -> Method overloading is a concept where multiple methods in the same class have the same name but different parameters. However, Python does not support traditional method overloading like Java or C++. Instead, it achieves similar behavior using default arguments and *args/**kwargs.

# %% [markdown]
# 12.  What is method overriding in OOP?
#
# -> Method overriding is a feature in Object-Oriented Programming (OOP) where a child class provides a specific implementation of a method that is already defined in its parent class. The overridden method in the child class must have the same name, parameters, and return type as in the parent class.

# %% [markdown]
# 13. What is a property decorator in Python?
#
# -> The property decorator (@property) in Python is used to define getter, setter, and deleter methods in an elegant way. It allows a method to be accessed like an attribute while still providing control over data access and modification.
#
# -> Key Benefits:
#   - Encapsulation - Controls how class attributes are accessed and modified.
#   - Readability - Allows access to methods like attributes (obj.value instead of obj.get_value()).
#   - Prevents Direct Modification - Enables validation and computed properties.

# %% [markdown]
# 14. Why is polymorphism important in OOP?
#
# -> Polymorphism is a key concept in Object-Oriented Programming (OOP) that allows different classes to use the same method name while exhibiting different behaviors. It enhances flexibility, scalability, and maintainability in software development.
#
# -> Key Reasons Why Polymorphism is Important:
#    - Code Reusability - The same interface can be used across multiple classes, reducing code duplication.
#    - Extensibility - New classes can implement existing methods without modifying the original code structure.
#    - Improved Maintainability - Allows changes in one part of the system without affecting other parts, making updates easier.
#    - Increases Flexibility - Enables objects of different classes to be treated uniformly, simplifying complex logic.
#    - Supports Method Overriding - Child classes can modify the behavior of parent class methods, ensuring more customized implementations.
#    - Reduces Code Complexity - Makes programs more scalable and easier to understand by using generalized code structures.

# %% [markdown]
# 15. What is an abstract class in Python?
#
# -> An abstract class in Python is a class that cannot be instantiated and is meant to be inherited by other classes. It serves as a blueprint for subclasses, enforcing the implementation of certain methods. Abstract classes are defined using the ABC (Abstract Base Class) module and contain at least one abstract method, which must be implemented by derived classes.

# %% [markdown]
# 16. What are the advantages of OOP?
#
# - Code Reusability - OOP promotes reusability through inheritance, allowing classes to reuse existing code instead of writing it from scratch.
#
# - Encapsulation - Data and methods are bundled together, protecting data from unintended modification and ensuring better control.
#
# - Abstraction - Hides complex implementation details and only exposes essential functionalities, making the code easier to use.
#
# - Polymorphism - Allows different classes to define the same method, making code more flexible and reducing redundancy.
#
# - Modularity and Maintainability - Divides programs into smaller, manageable objects, making debugging, updating, and scaling easier.
#
# - Improved Security - Restricts direct access to sensitive data using access modifiers (private, protected), preventing accidental changes.
#
# - Scalability - OOP structures code in a way that supports adding new features with minimal impact on existing code.

# %% [markdown]
# 17. What is the difference between a class variable and an instance variable?
#
# - Class Variable is a variable shared across all instances of a class whereas Instance Variable is a variable unique to each instance of a class.
#
# - Class Variable is a variable defined inside the class but outside any method whereas Instance Variable defined inside the constructor (__init__) using self

# %% [markdown]
# 18. What is multiple inheritance in Python?
#
# -> Multiple inheritance is a feature in Python where a class can inherit attributes and methods from more than one parent class. This allows a child class to access functionalities from multiple base classes, promoting code reuse and flexibility.

# %%
#example 18

class Parent1:
    def feature1(self):
        print("Feature from Parent1")

class Parent2:
    def feature2(self):
        print("Feature from Parent2")

class Child(Parent1, Parent2):  # Multiple Inheritance
    def feature3(self):
        print("Feature from Child")

# Creating an object of Child
obj = Child()
obj.feature1()  # Inherited from Parent1
obj.feature2()  # Inherited from Parent2
obj.feature3()  # Defined in Child
# Out:
# Feature from Parent1
# Feature from Parent2
# Feature from Child

# %% [markdown]
# 19. Explain the purpose of ''__str__' and '__repr__' ' methods in Python?
#
# -> The __str__ and __repr__ methods in Python are used to define string representations of objects, but they serve different purposes.
#
# -> The __str__ method provides a human-readable and user-friendly description of an object, mainly used when calling print() or str().
#
# -> On the other hand, the __repr__ method is intended for developers and returns an unambiguous, detailed representation of the object, ideally in a format that can be used to recreate it.
#
# -> When repr() is called or an object is displayed in an interactive console, __repr__ is invoked. For example, if a class Person has both methods, __str__ might return "Person: Aditi, Age: 25", while __repr__ could return "Person('Aditi', 25)".
#
# -> This distinction helps ensure that objects have both a readable format for users and a precise format for debugging and development.

# %% [markdown]
# 20. What is the significance of the 'super()' function in Python?
#
# -> Significance of super() in Python
# - Code Reusability
#   - Allows reuse of parent class methods without rewriting code.
# - Avoids Redundancy
#   - Prevents duplication by directly calling the parent class methods.
# - Supports Method Overriding
#   - Enables child classes to extend or modify parent class behavior while still using the parent's implementation.
# - Handles Multiple Inheritance
#   - Helps resolve the Method Resolution Order (MRO) issue in complex inheritance hierarchies.
# - Improves Maintainability
#   - Makes code more readable, structured, and easier to modify.

# %% [markdown]
# 21.  What is the significance of the __del__ method in Python?
#
# -> Significance of the __del__ Method in Python
#
# - Automatic Resource Cleanup
#   - Ensures proper release of resources (e.g., closing files, releasing database connections) when an object is deleted.
#
# - Garbage Collection
#   - Helps in memory management by executing cleanup tasks before an object is destroyed.
# - Avoiding Memory Leaks
#   - Prevents resource leaks by explicitly handling cleanup operations.
# - Finalization of Objects
#   - Provides a way to define custom destruction logic for objects before they are removed from memory.

# %% [markdown]
# 22. What is the difference between @staticmethod and @classmethod in Python?
#
# - @staticmethod are not bound to class or instance whereas @classmethod are bound to the class, not instance.
#
# - @staticmethod takes no self or cls whereas @classmethod takes cls as the first parameter
#
# - @staticmethod has no access to class or instance variables whereas @classmethod can access and modify class variables

# %% [markdown]
# 23. How does polymorphism work in Python with inheritance?
#
# -> Polymorphism allows different classes to define methods with the same name but different behaviors. In inheritance-based polymorphism, a child class overrides a parent class method, enabling dynamic method resolution at runtime.

# %%
#example 23

class Animal:
    def sound(self):
        return "Some sound"

class Dog(Animal):
    def sound(self):  # Overriding the parent method
        return "Bark"

class Cat(Animal):
    def sound(self):  # Overriding the parent method
        return "Meow"

# Using polymorphism
animals = [Dog(), Cat(), Animal()]

for animal in animals:
    print(animal.sound())  # Calls the overridden method dynamically
# Out:
# Bark
# Meow
# Some sound

# %% [markdown]
# 24. What is method chaining in Python OOP?
#
# -> Method chaining in Python OOP is a technique where multiple methods are called on the same object in a single statement. Each method returns self (the instance), allowing subsequent method calls to be linked together.

# %%
#example 24

class Person:
    def __init__(self, name):
        self.name = name

    def set_age(self, age):
        self.age = age
        return self  # Returning self for chaining

    def set_city(self, city):
        self.city = city
        return self  # Returning self for chaining

    def display(self):
        print(f"Name: {self.name}, Age: {self.age}, City: {self.city}")
        return self  # Returning self for further chaining if needed

# Method Chaining
p = Person("Aditi").set_age(25).set_city("Mumbai").display()
# Out:
# Name: Aditi, Age: 25, City: Mumbai

# %% [markdown]
# 25. What is the purpose of the __call__ method in Python?
#
# -> The __call__ method in Python allows an instance of a class to be called as a function. When defined in a class, it enables objects of that class to be invoked using parentheses, like object(), executing the logic inside __call__.

# %% [markdown]
# Practical Questions

# %%
#1.  Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".

class Animal:
  def speak(self):
    print("Every animal has its own way of speaking")

class Dog(Animal):
  def speak(self):
    print("Barks !!!!")

animal = Animal()
dog = Dog()
animal.speak()
dog.speak()
# Out:
# Every animal has its own way of speaking
# Barks !!!!

# %%
#2.  Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.

from abc import ABC, abstractmethod
import math

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass  # Abstract method to be implemented in derived classes

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Creating objects of derived classes
circle = Circle(5)
rectangle = Rectangle(4, 6)

# Displaying area of shapes
print(f"Area of Circle: {circle.area():.2f}")
print(f"Area of Rectangle: {rectangle.area()}")
# Out:
# Area of Circle: 78.54
# Area of Rectangle: 24

# %%
#3.  Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.

class Vehicle:
    def __init__(self, vehicle_type):
        self.vehicle_type = vehicle_type

    def show_type(self):
        print(f"This is a {self.vehicle_type}.")

class Car(Vehicle):
    def __init__(self, brand, model):
        super().__init__("Car")
        self.brand = brand
        self.model = model

    def show_details(self):
        print(f"Car Brand: {self.brand}, Model: {self.model}")

class ElectricCar(Car):
    def __init__(self, brand, model, battery_capacity):
        super().__init__(brand, model)
        self.battery_capacity = battery_capacity

    def show_battery(self):
        print(f"Battery Capacity: {self.battery_capacity} kWh")

# Creating an object of ElectricCar
tesla = ElectricCar("Tesla", "Model S", 100)

# Displaying details using multi-level inheritance
tesla.show_type()       # Inherited from Vehicle
tesla.show_details()    # Inherited from Car
tesla.show_battery()    # Defined in ElectricCar
# Out:
# This is a Car.
# Car Brand: Tesla, Model: Model S
# Battery Capacity: 100 kWh

# %%
#4.  Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.

class Bird:
    def fly(self):
        print("Bird is flying...")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high in the sky! ")

class Penguin(Bird):
    def fly(self):
        print("Penguins can't fly, but they swim! ")

# Function demonstrating runtime polymorphism
def bird_flight(bird):
    bird.fly()

# Creating objects of derived classes
sparrow = Sparrow()
penguin = Penguin()

# Calling the fly method dynamically
bird_flight(sparrow)
bird_flight(penguin)
# Out:
# Sparrow flies high in the sky!
# Penguins can't fly, but they swim!

# %%
#5. . Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.

class BankAccount:
    def __init__(self, account_holder, balance=0):
        self.account_holder = account_holder
        self.__balance = balance  # Private attribute

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited ${amount}. New balance: ${self.__balance}")
        else:
            print("Deposit amount must be positive.")

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrew ${amount}. New balance: ${self.__balance}")
        else:
            print("Insufficient funds or invalid amount.")

    def check_balance(self):
        return f"Current balance: ${self.__balance}"

# Creating a BankAccount object
account = BankAccount("Alice", 1000)

# Performing transactions
account.deposit(500)
account.withdraw(300)
print(account.check_balance())
# Out:
# Deposited $500. New balance: $1500
# Withdrew $300. New balance: $1200
# Current balance: $1200

# %%
#6.  Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().


class Instrument:
    def play(self):
        print("Playing an instrument...")

class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar ")

class Piano(Instrument):
    def play(self):
        print("Playing the piano ")

# Function demonstrating runtime polymorphism
def play_instrument(instrument):
    instrument.play()

# Creating objects of derived classes
guitar = Guitar()
piano = Piano()

# Calling the play method dynamically
play_instrument(guitar)
play_instrument(piano)
# Out:
# Strumming the guitar
# Playing the piano

# %%
#7.  Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.

class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# Using class method to add numbers
sum_result = MathOperations.add_numbers(10, 5)

# Using static method to subtract numbers
difference_result = MathOperations.subtract_numbers(10, 5)

# Displaying results
print(f"Sum: {sum_result}")
print(f"Difference: {difference_result}")
# Out:
# Sum: 15
# Difference: 5

# %%
#8.  Implement a class Person with a class method to count the total number of persons created.

class Person:
    count = 0  # Class variable to store the count of persons

    def __init__(self, name, age):
        self.name = name
        self.age = age
        Person.count += 1  # Increment count when a new person is created

    @classmethod
    def total_persons(cls):
        return cls.count  # Return the total number of persons

# Creating Person objects
person1 = Person("Alice", 25)
person2 = Person("Bob", 30)
person3 = Person("Charlie", 22)

# Displaying the total number of persons created
print(f"Total persons created: {Person.total_persons()}")
# Out:
# Total persons created: 3

# %%
#9. Write a class Fraction with attributes numerator and denominator. Override the str method to display th fraction as "numerator/denominator".

class Fraction:
    def __init__(self, numerator, denominator):
        if denominator == 0:
            raise ValueError("Denominator cannot be zero")
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# Creating Fraction objects
frac1 = Fraction(3, 5)
frac2 = Fraction(7, 2)

# Displaying the fractions
print(f"Fraction 1: {frac1}")
print(f"Fraction 2: {frac2}")
# Out:
# Fraction 1: 3/5
# Fraction 2: 7/2

# %%
#10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.

class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"

# Creating Vector objects
v1 = Vector(3, 4)
v2 = Vector(1, 2)

# Adding vectors using operator overloading
v3 = v1 + v2

# Displaying the result
print(f"Vector 1: {v1}")
print(f"Vector 2: {v2}")
print(f"Sum of Vectors: {v3}")
# Out:
# Vector 1: (3, 4)
# Vector 2: (1, 2)
# Sum of Vectors: (4, 6)

# %%
#11.  Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old.

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# Creating an object of the Person class
person1 = Person("Aditi", 25)

# Calling the greet method
person1.greet()
# Out:
# Hello, my name is Aditi and I am 25 years old.

# %%
#12.  Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.

class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades  # List of grades

    def average_grade(self):
        if len(self.grades) == 0:
            return 0  # Avoid division by zero
        return sum(self.grades) / len(self.grades)

# Creating an object of the Student class
student1 = Student("Alice", [85, 90, 78, 92, 88])

# Displaying the average grade
print(f"{student1.name}'s Average Grade: {student1.average_grade():.2f}")
# Out:
# Alice's Average Grade: 86.60

# %%
#13.  Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.

class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Creating an object of the Rectangle class
rect = Rectangle()
rect.set_dimensions(5, 10)

# Displaying the area
print(f"Area of the rectangle: {rect.area()}")
# Out:
# Area of the rectangle: 50

# %%
#14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.

class Employee:
    def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate

class Manager(Employee):
    def __init__(self, name, hours_worked, hourly_rate, bonus):
        super().__init__(name, hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        return super().calculate_salary() + self.bonus

# Creating objects
employee1 = Employee("Alice", 40, 20)
manager1 = Manager("Bob", 45, 30, 500)

# Displaying salaries
print(f"{employee1.name}'s Salary: ${employee1.calculate_salary()}")
print(f"{manager1.name}'s Salary (with bonus): ${manager1.calculate_salary()}")
# Out:
# Alice's Salary: $800
# Bob's Salary (with bonus): $1850

# %%
#15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product

class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

# Creating an object of the Product class
product1 = Product("Laptop", 800, 2)

# Displaying the total price
print(f"Total price of {product1.name}: ${product1.total_price()}")

# %%
# 16.  Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method

from abc import ABC, abstractmethod

# Abstract class
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

# Derived class Cow
class Cow(Animal):
    def sound(self):
        return "Moo"

# Derived class Sheep
class Sheep(Animal):
    def sound(self):
        return "Baa"

# Creating objects
cow = Cow()
sheep = Sheep()

# Displaying sounds
print(f"Cow: {cow.sound()}")
print(f"Sheep: {sheep.sound()}")
# Out:
# Cow: Moo
# Sheep: Baa

# %%
#17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.

class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"Title: {self.title}, Author: {self.author}, Year Published: {self.year_published}"

# Creating an object of the Book class
book1 = Book("The Great Gatsby", "F. Scott Fitzgerald", 1925)

# Displaying book information
print(book1.get_book_info())
# Out:
# Title: The Great Gatsby, Author: F. Scott Fitzgerald, Year Published: 1925

# %%
#18.  Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.

class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

    def display_info(self):
        print(f"Address: {self.address}, Price: ${self.price}")

class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

    def display_info(self):
        print(f"Address: {self.address}, Price: ${self.price}, Number of Rooms: {self.number_of_rooms}")

# Creating objects
house1 = House("123 Main St", 250000)
mansion1 = Mansion("456 Luxury Ave", 2000000, 10)

# Displaying information
house1.display_info()
mansion1.display_info()
# Out:
# Address: 123 Main St, Price: $250000
# Address: 456 Luxury Ave, Price: $2000000, Number of Rooms: 10
